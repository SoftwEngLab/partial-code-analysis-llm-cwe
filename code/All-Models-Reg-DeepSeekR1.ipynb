# %%
import openai
from openai import OpenAI
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
from concurrent.futures import ThreadPoolExecutor, as_completed
import litellm
import os
import json
import re
from datetime import datetime
import argparse
import requests
from together import Together
# Global variable for Vertex AI credential
VERTEX_AI_CREDENTIAL = ""

# %%
client = openai

# %%
def query_litellm(prompt, llm_model, temperature):
    """
    Queries the VertexAI API with the specified parameters and returns the response.
    """
    try:
        response = litellm.completion(
            model=llm_model,
            temperature=temperature,
            messages=[
                {
                    "role": "system",
                    "content": "You are a helpful assistant. You must LIMIT YOUR RESPONSE TO 130 TOKENS.",
                },
                {"role": "user", "content": prompt},
            ],
            vertex_credentials=VERTEX_AI_CREDENTIAL,
        )
        return response
    except Exception as e:
        print(f"An error occurred during API query: {e}")
    return None
    
def query_openai_o1(prompt, model, temperature):
    client = openai
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "You are a helpful assistant. Limit your response to 500 tokens."},
            {"role": "user", "content": prompt},
        ])
    return response
    
def query_openai(prompt, model, temperature, mode):
    """
    Queries the OpenAI API or Hugging Face API depending on the mode.
    """
    try:
        if mode == "deepseek":
            client = OpenAI(
                base_url="https://huggingface.co/api/inference-proxy/together",
                api_key=""
            )
            response = client.chat.completions.create(
                model=model,
                messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
                temperature=temperature,
                max_tokens=150,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stream=False
            )
            return response
        elif mode == "deepseek-r1-together":
            print("HERE!!")
            os.environ['TOGETHER_API_KEY'] = ''
            client = Together()
            response = client.chat.completions.create(
                model="deepseek-ai/DeepSeek-R1",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
                temperature=temperature,
                top_p=1,
                seed=42
            )
            return response
        elif mode == "deepseek-r1-deepinfra":

            # Create an OpenAI client with your deepinfra token and endpoint
            openai = OpenAI(
                api_key="",
                base_url="https://api.deepinfra.com/v1/openai",
            )
            
            # chat_completion = openai.chat.completions.create(
            #     model="deepseek-ai/DeepSeek-R1",
            #     messages=[{"role": "user", "content": "Hello"}],
            # )

            response = openai.chat.completions.create(
              model="deepseek-ai/DeepSeek-R1",
              messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
              temperature=temperature,
              top_p=1,
              stream=False
            )

            return response

        elif mode == "deepseek-r1-github":          
            print("...github!")
            endpoint = "https://models.inference.ai.azure.com"
            model_name = "DeepSeek-R1"
            
            os.environ['GITHUB_TOKEN'] = ''
            token = os.environ["GITHUB_TOKEN"]
            
            client = ChatCompletionsClient(
                endpoint=endpoint,
                credential=AzureKeyCredential(token),
            )
            
            response = client.complete(
                messages=[
                    SystemMessage(content="You are a helpful assistant. Limit your response to 130 tokens."),
                    UserMessage(content=prompt),
                ],
                temperature=temperature,
                top_p=1.0,
                model=model_name
            )
            return response
        elif mode == "deepseek-r1-azure":
            os.environ['ENDPOINT'] = 'https://aistudioaiservices133462205434.services.ai.azure.com/models'
            os.environ['API_KEY'] = ''
            os.environ['MODEL'] = 'DeepSeek-R1'
            
            endpoint = os.environ["ENDPOINT"]
            api_key = os.environ["API_KEY"]
            model_name = os.environ["MODEL"]
            
            client = ChatCompletionsClient(
                endpoint=endpoint,
                credential=AzureKeyCredential(api_key),
            )
            
            response = client.complete(
                messages=[
                    SystemMessage(content="You are a helpful assistant. Limit your response to 130 tokens."),
                    UserMessage(content=prompt),
                ],
                temperature=temperature,
                top_p=1.0,
                model=model_name
            )

            return response
        elif mode == "deepseek-r1-nvidia":
            client = OpenAI(
                base_url = "https://integrate.api.nvidia.com/v1",
                api_key="nvapi-",
            )

            response = client.chat.completions.create(
              model="deepseek-ai/deepseek-r1",
              messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
              temperature=temperature,
              top_p=1,
              stream=False
            )
            return response
        elif mode == "deepseek-r1-api":
            client = OpenAI(api_key="sk-", base_url="https://api.deepseek.com")
            
            response = client.chat.completions.create(
                model="deepseek-reasoner",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
                temperature=temperature,
              top_p=1,
              stream=False
            )
            print(response)
            return response
            
        elif mode == "hf_endpoint":
            return query_hf_api(prompt, temperature)
        elif mode == "o1":
            return query_openai_o1(prompt, model, temperature)
        elif mode == "bedrock":
            return query_litellm(prompt, model, temperature)
        else:
            print("got here")
            client = openai
            response = client.chat.completions.create(
                model=model,
                messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
                temperature=temperature,
                max_tokens=150,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stream=False
            )
            return response
    except Exception as e:
        print(f"An error occurred during API query: {e}")
    return None

def query_hf_api(prompt, temperature):
    """
    Queries the Hugging Face API.
    """
    # payload = {
    #     "inputs": prompt,
    #     "parameters": {
    #         "temperature": temperature,
    #         "max_new_tokens": 150
    #     }
    #}
    try:
        #response = requests.post(HF_API_URL, headers=HF_HEADERS, json=payload)
        #response.raise_for_status()
        #return response.json()

        # define client openai with the endpoint server url
        client = OpenAI(
        	base_url="https://ue4xb2y39sfo803n.us-east-1.aws.endpoints.huggingface.cloud/v1/", 
            api_key="" 
            )
        
        response = client.chat.completions.create(
            model="tgi",
            messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
            top_p=None,
            temperature=None,
            max_tokens=1000,
            stream=False,
            seed=None,
            stop=None,
            frequency_penalty=None,
            presence_penalty=None
            )
        
        return response
    except requests.exceptions.RequestException as e:
        print(f"An error occurred while querying the Hugging Face API: {e}")
    return None

def extract_response_content_litellm(response):
    """
    Extracts the content from the API response for serialization.
    """
    try:
        return response["choices"][0]["message"]["content"]
    except (KeyError, TypeError) as e:
        print(f"Error extracting response content: {e}")
        print("Full response:", response)
    return None
    
def extract_response_content(response):
    """
    Extracts the content from the API response for serialization.
    """
    try:
        return response.choices[0].message.content if response else None
    except (KeyError, TypeError, AttributeError) as e:
        print(f"Error extracting response content: {e}")
        print("Full response:", response)
    return None

def read_prompt_from_file(file_path):
    """
    Reads the prompt from a file.
    """
    try:
        with open(file_path, "r") as file:
            return file.read()
    except FileNotFoundError:
        print(f"Error: The file {file_path} does not exist.")
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
    return None

def save_responses_to_json(responses, folder_path, model, temperature, trial):
    """
    Saves all responses to a single JSON file.
    """
    timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
    output_file_name = f"output_responses_{model.replace('/', '_')}_temp{temperature}_{timestamp}_trial_{trial}.json"
    output_file_path = os.path.join(folder_path, output_file_name)
    try:
        with open(output_file_path, 'w') as file:
            json.dump(responses, file, indent=4)
        print(f"------------Responses saved to {output_file_path}---------")
    except Exception as e:
        print(f"Failed to save the file: {e}")
def save_response_to_json(response_content, folder_path, model, trial, filename):
    """
    Saves the response content to a JSON file, ensuring no overwrite.
    """
    output_file_name = f"{filename.replace('.txt', '_response')}_{model.replace('/', '_')}_trial_{trial}.json"
    output_file_path = os.path.join(folder_path, output_file_name)
    
    if not os.path.exists(output_file_path):
        try:
            with open(output_file_path, 'w') as file:
                json.dump({filename: response_content}, file, indent=4)
            print(f"Response saved to {output_file_path}")
        except Exception as e:
            print(f"Failed to save the file: {e}")
    else:
        print(f"Skipping {filename}: Response file already exists.")

def process_file(filename, folder_path, model, temperature, trial, mode):
    """
    Processes a single file, checking if a response already exists before querying.
    """
    output_file_name = f"{filename.replace('.txt', '_response')}_{model.replace('/', '_')}_trial_{trial}.json"
    output_file_path = os.path.join(folder_path, output_file_name)
    
    if os.path.exists(output_file_path):
        print(f"Skipping {filename}: Response already exists in {output_file_path}")
        return filename, None
    
    file_path = os.path.join(folder_path, filename)
    prompt_text = read_prompt_from_file(file_path)
    print("Prompt text for ... ", filename)
    if prompt_text:
        print(f"Processing file: {filename}")
        response = query_openai(prompt_text, model, temperature, mode)
        if mode == "bedrock":
            content = extract_response_content_litellm(response)
        else:
            content = extract_response_content(response)
        
        if content:
            save_response_to_json(content, folder_path, model, trial, filename)
            return filename, content
    return filename, None

def process_folder_parallel(folder_path, model, temperature, trial, mode, max_workers=10):
    """
    Processes all eligible text files in the folder in parallel.
    """
    files = [f for f in os.listdir(folder_path) if re.match(r'output_sample_(\d+)\.txt', f)]
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_file = {executor.submit(process_file, file, folder_path, model, temperature, trial, mode): file for file in files}
        for future in as_completed(future_to_file):
            future.result()

def combine_all_responses(folder_path, model, temperature, trial):
    """
    Combines all response JSONs into a single JSON file only if every file 
    matching output_sample_{n}.txt has a corresponding 
    output_sample_{n}_response_{model}_trial_{trial}.json.
    """
    responses = {}
    pattern = re.compile(r"^output_sample_(\d+)\.txt$")  # Matches files like output_sample_1.txt

    # Get all filenames in the folder
    files_in_folder = set(os.listdir(folder_path))

    # Collect all `output_sample_{n}.txt` and check if each has a corresponding JSON
    txt_files = {file for file in files_in_folder if pattern.match(file)}
    json_files = {
        file.replace(".txt", f"_response_{model.replace('/', '_')}_trial_{trial}.json")
        for file in txt_files
    }

    # Check if all expected JSON files exist
    if not json_files.issubset(files_in_folder):
        print(">>>>>>>>>>>>>>>Not all .txt files have their corresponding .json files. Aborting combination.<<<<<<<<<<<<<<<")
        return

    # If all JSON files exist, process them
    for json_file in json_files:
        json_path = os.path.join(folder_path, json_file)
        try:
            with open(json_path, 'r') as f:
                data = json.load(f)
                responses.update(data)
        except Exception as e:
            print(f"Error reading {json_file}: {e}")
    
    save_responses_to_json(responses, folder_path, model, temperature, trial)

# %%
os.environ['OPENAI_API_KEY'] = 'sk-proj-'

# %%
cwe_list = ["cwe-190", "cwe-078", "cwe-416", "cwe-476"]
experiment_list = ["exp_0_1", "exp_0_2", "exp_15_2", "exp_16", "exp_17", "exp_17_inherent", "exp_18", "exp_15", "exp_25"]
#experiment_list = ["exp_0_1", "exp_0_2", "exp_15_2", "exp_16", "exp_17", "exp_17_inherent", "exp_18", "exp_15"]

for cwe in cwe_list:
    for exp in experiment_list:
        folder_path_before = f"/Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/{cwe}/{exp}/func_src_before"
        folder_path_after = f"/Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/{cwe}/{exp}/func_src_after"
        #model = "deepseek-ai/DeepSeek-R1-Distill-Qwen-32B"
        #model = "o1"
        #model = "bedrock/us.anthropic.claude-3-5-sonnet-20241022-v2:0"
        model = "bedrock/meta.llama3-1-70b-instruct-v1:0"

        #model = "deepseek-ai/DeepSeek-R1"
        temperature = 0.7
        trial = 0
        mw = 10
        mode = "openai"
        if model == "deepseek-ai/DeepSeek-R1":
            mode = "deepseek-r1-together"
            mw = 100
        elif model == "deepseek-ai/DeepSeek-R1-Distill-Qwen-32B":
            mode = "hf_endpoint"
            mw = 4
        elif model == "o1":
            mode = "o1"
            mw = 5
        elif model == "bedrock/us.anthropic.claude-3-5-sonnet-20241022-v2:0":
            print("yes......")
            mode = "bedrock"
            mw = 10
        elif model == "bedrock/meta.llama3-1-70b-instruct-v1:0":
            mode = "bedrock"
            mw = 10

        print(folder_path_before, model, temperature, trial, mode, mw)
        process_folder_parallel(folder_path_before, model, temperature, trial, mode, max_workers=mw)
        combine_all_responses(folder_path_before, model, temperature, trial)

        print(folder_path_after, model, temperature, trial, mode, mw)
        process_folder_parallel(folder_path_after, model, temperature, trial, mode, max_workers=mw)
        combine_all_responses(folder_path_after, model, temperature, trial)
# Out:
# /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before bedrock/meta.llama3-1-70b-instruct-v1:0 0.7 0 bedrock 10
# Prompt text for ...  output_sample_27.txt
# Processing file: output_sample_27.txt
# Prompt text for ...  output_sample_32.txt
# Processing file: output_sample_32.txt
# Prompt text for ...  output_sample_33.txt
# Processing file: output_sample_33.txt
# Prompt text for ...  output_sample_30.txt
# Processing file: output_sample_30.txt
# Prompt text for ...  output_sample_24.txt
# Processing file: output_sample_24.txt
# Prompt text for ...  output_sample_26.txt
# Processing file: output_sample_26.txt
# Prompt text for ...  output_sample_18.txt
# Processing file: output_sample_18.txt
# Prompt text for ... Prompt text for ...  output_sample_25.txt
# Processing file: output_sample_25.txt
#  output_sample_31.txt
# Processing file: output_sample_31.txt
# Prompt text for ...  output_sample_19.txt
# Processing file: output_sample_19.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_30_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.jsonResponse saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_18_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
#
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_31_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_33_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_20.txt
# Processing file: output_sample_20.txt
# Prompt text for ...  output_sample_21.txt
# Processing file: output_sample_21.txt
# Prompt text for ...  output_sample_35.txt
# Processing file: output_sample_35.txt
# Prompt text for ...  output_sample_34.txt
# Processing file: output_sample_34.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_19_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_22.txt
# Processing file: output_sample_22.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_26_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_36.txt
# Processing file: output_sample_36.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_25_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_37.txt
# Processing file: output_sample_37.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_24_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_23.txt
# Processing file: output_sample_23.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_32_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_8.txt
# Processing file: output_sample_8.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_27_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_9.txt
# Processing file: output_sample_9.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_21_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_4.txt
# Processing file: output_sample_4.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_35_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_22_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_5.txt
# Processing file: output_sample_5.txt
# Prompt text for ...  output_sample_7.txt
# Processing file: output_sample_7.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_34_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_6.txt
# Processing file: output_sample_6.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_37_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_2.txt
# Processing file: output_sample_2.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_36_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_3.txt
# Processing file: output_sample_3.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_23_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_1.txt
# Processing file: output_sample_1.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_9_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_12.txt
# Processing file: output_sample_12.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_6_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_13.txt
# Processing file: output_sample_13.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_8_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_11.txt
# Processing file: output_sample_11.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_4_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_10.txt
# Processing file: output_sample_10.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_5_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_38.txt
# Processing file: output_sample_38.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_7_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_14.txt
# Processing file: output_sample_14.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_3_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_28.txt
# Processing file: output_sample_28.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_12_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_29.txt
# Processing file: output_sample_29.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_1_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_15.txt
# Processing file: output_sample_15.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_11_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_17.txt
# Processing file: output_sample_17.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_13_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_16.txt
# Processing file: output_sample_16.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_2_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_14_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_38_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_28_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_15_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_17_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_16_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_29_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_10_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_sample_20_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# ------------Responses saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_before/output_responses_bedrock_meta.llama3-1-70b-instruct-v1:0_temp0.7_20250214111321_trial_0.json---------
# /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after bedrock/meta.llama3-1-70b-instruct-v1:0 0.7 0 bedrock 10
# Prompt text for ...  output_sample_32.txt
# Processing file: output_sample_32.txt
# Prompt text for ...  output_sample_33.txt
# Processing file: output_sample_33.txt
# Prompt text for ...  output_sample_26.txt
# Processing file: output_sample_26.txt
# Prompt text for ...  output_sample_27.txt
# Processing file: output_sample_27.txt
# Prompt text for ...  output_sample_30.txt
# Processing file: output_sample_30.txt
# Prompt text for ...  output_sample_25.txt
# Processing file: output_sample_25.txt
# Prompt text for ...  output_sample_18.txt
# Processing file: output_sample_18.txt
# Prompt text for ...  output_sample_24.txt
# Processing file: output_sample_24.txt
# Prompt text for ...  output_sample_31.txt
# Processing file: output_sample_31.txt
# Prompt text for ...  output_sample_19.txt
# Processing file: output_sample_19.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_19_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_35.txt
# Processing file: output_sample_35.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_27_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_21.txt
# Processing file: output_sample_21.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_33_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_20.txt
# Processing file: output_sample_20.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_30_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_34.txt
# Processing file: output_sample_34.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_18_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_22.txt
# Processing file: output_sample_22.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_24_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_36.txt
# Processing file: output_sample_36.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_31_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_37.txt
# Processing file: output_sample_37.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_25_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_23.txt
# Processing file: output_sample_23.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_32_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_8.txt
# Processing file: output_sample_8.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_26_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_9.txt
# Processing file: output_sample_9.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_22_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_21_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_4.txt
# Processing file: output_sample_4.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_37_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_5.txt
# Processing file: output_sample_5.txt
# Prompt text for ...  output_sample_7.txt
# Processing file: output_sample_7.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_23_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_35_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_6.txt
# Processing file: output_sample_6.txt
# Prompt text for ...  output_sample_2.txt
# Processing file: output_sample_2.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_34_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_9_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_3.txt
# Processing file: output_sample_3.txt
# Prompt text for ...  output_sample_1.txt
# Processing file: output_sample_1.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_36_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_12.txt
# Processing file: output_sample_12.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_8_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_13.txt
# Processing file: output_sample_13.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_6_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_11.txt
# Processing file: output_sample_11.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_12_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_10.txt
# Processing file: output_sample_10.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_5_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_4_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_7_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_38.txt
# Processing file: output_sample_38.txt
# Prompt text for ...  output_sample_14.txt
# Processing file: output_sample_14.txt
# Prompt text for ...  output_sample_28.txt
# Processing file: output_sample_28.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_13_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_29.txt
# Processing file: output_sample_29.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_3_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_15.txt
# Processing file: output_sample_15.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_11_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_17.txt
# Processing file: output_sample_17.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_28_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_16.txt
# Processing file: output_sample_16.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_14_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_38_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_17_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_15_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_1_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_2_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_29_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_16_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_10_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_sample_20_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# ------------Responses saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_1/func_src_after/output_responses_bedrock_meta.llama3-1-70b-instruct-v1:0_temp0.7_20250214111405_trial_0.json---------
# /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before bedrock/meta.llama3-1-70b-instruct-v1:0 0.7 0 bedrock 10
# Prompt text for ...  output_sample_33.txt
# Processing file: output_sample_33.txt
# Prompt text for ...  output_sample_32.txt
# Processing file: output_sample_32.txt
# Prompt text for ...  output_sample_26.txt
# Processing file: output_sample_26.txt
# Prompt text for ...  output_sample_18.txt
# Processing file: output_sample_18.txt
# Prompt text for ...  output_sample_27.txt
# Processing file: output_sample_27.txt
# Prompt text for ...  output_sample_24.txt
# Processing file: output_sample_24.txt
# Prompt text for ...  output_sample_30.txt
# Processing file: output_sample_30.txt
# Prompt text for ...  output_sample_25.txt
# Processing file: output_sample_25.txt
# Prompt text for ...  output_sample_19.txt
# Processing file: output_sample_19.txt
# Prompt text for ...  output_sample_31.txt
# Processing file: output_sample_31.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_32_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_35.txt
# Processing file: output_sample_35.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_30_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_25_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_21.txt
# Processing file: output_sample_21.txt
# Prompt text for ...  output_sample_20.txt
# Processing file: output_sample_20.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_27_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_34.txt
# Processing file: output_sample_34.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_33_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_22.txt
# Processing file: output_sample_22.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_19_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_36.txt
# Processing file: output_sample_36.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_18_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_31_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_23.txt
# Processing file: output_sample_23.txt
# Prompt text for ...  output_sample_37.txt
# Processing file: output_sample_37.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_26_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_8.txt
# Processing file: output_sample_8.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_24_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_9.txt
# Processing file: output_sample_9.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_35_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_4.txt
# Processing file: output_sample_4.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_21_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_5.txt
# Processing file: output_sample_5.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_34_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_7.txt
# Processing file: output_sample_7.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_37_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_22_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_6.txt
# Processing file: output_sample_6.txt
# Prompt text for ...  output_sample_2.txt
# Processing file: output_sample_2.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_36_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_3.txt
# Processing file: output_sample_3.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_9_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_1.txt
# Processing file: output_sample_1.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_23_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_12.txt
# Processing file: output_sample_12.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_8_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_13.txt
# Processing file: output_sample_13.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_4_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_6_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_11.txt
# Processing file: output_sample_11.txt
# Prompt text for ...  output_sample_10.txt
# Processing file: output_sample_10.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_7_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_38.txt
# Processing file: output_sample_38.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_5_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_14.txt
# Processing file: output_sample_14.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_3_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_12_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_28.txt
# Processing file: output_sample_28.txt
# Prompt text for ...  output_sample_29.txt
# Processing file: output_sample_29.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_2_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_15.txt
# Processing file: output_sample_15.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_13_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_17.txt
# Processing file: output_sample_17.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_11_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_16.txt
# Processing file: output_sample_16.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_1_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_14_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_28_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_38_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_15_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_17_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_16_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_29_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_10_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_sample_20_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# ------------Responses saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_before/output_responses_bedrock_meta.llama3-1-70b-instruct-v1:0_temp0.7_20250214111448_trial_0.json---------
# /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after bedrock/meta.llama3-1-70b-instruct-v1:0 0.7 0 bedrock 10
# Prompt text for ...  output_sample_33.txt
# Processing file: output_sample_33.txt
# Prompt text for ...  output_sample_30.txt
# Processing file: output_sample_30.txt
# Prompt text for ...  output_sample_26.txt
# Processing file: output_sample_26.txt
# Prompt text for ...  output_sample_24.txt
# Processing file: output_sample_24.txt
# Prompt text for ...  output_sample_25.txt
# Processing file: output_sample_25.txt
# Prompt text for ...  output_sample_32.txt
# Processing file: output_sample_32.txt
# Prompt text for ...  output_sample_27.txt
# Processing file: output_sample_27.txt
# Prompt text for ...  output_sample_31.txt
# Processing file: output_sample_31.txt
# Prompt text for ...  output_sample_18.txt
# Processing file: output_sample_18.txt
# Prompt text for ...  output_sample_19.txt
# Processing file: output_sample_19.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_24_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_35.txt
# Processing file: output_sample_35.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_31_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_21.txt
# Processing file: output_sample_21.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_33_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_20.txt
# Processing file: output_sample_20.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_25_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_34.txt
# Processing file: output_sample_34.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_19_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_18_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_22.txt
# Processing file: output_sample_22.txt
# Prompt text for ...  output_sample_36.txt
# Processing file: output_sample_36.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_30_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_37.txt
# Processing file: output_sample_37.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_27_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_23.txt
# Processing file: output_sample_23.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_32_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_8.txt
# Processing file: output_sample_8.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_26_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_9.txt
# Processing file: output_sample_9.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_35_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_4.txt
# Processing file: output_sample_4.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_21_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_5.txt
# Processing file: output_sample_5.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_22_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_7.txt
# Processing file: output_sample_7.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_23_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_6.txt
# Processing file: output_sample_6.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_37_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_2.txt
# Processing file: output_sample_2.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_9_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_36_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_3.txt
# Processing file: output_sample_3.txt
# Prompt text for ...  output_sample_1.txt
# Processing file: output_sample_1.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_34_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_12.txt
# Processing file: output_sample_12.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_4_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_13.txt
# Processing file: output_sample_13.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_6_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_8_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_11.txt
# Processing file: output_sample_11.txt
# Prompt text for ...  output_sample_10.txt
# Processing file: output_sample_10.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_5_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_38.txt
# Processing file: output_sample_38.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_7_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_14.txt
# Processing file: output_sample_14.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_12_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_28.txt
# Processing file: output_sample_28.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_3_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_29.txt
# Processing file: output_sample_29.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_13_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_15.txt
# Processing file: output_sample_15.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_2_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_17.txt
# Processing file: output_sample_17.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_11_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_16.txt
# Processing file: output_sample_16.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_1_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_38_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_28_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_14_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_17_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_15_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_16_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_29_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_10_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_sample_20_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# ------------Responses saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_0_2/func_src_after/output_responses_bedrock_meta.llama3-1-70b-instruct-v1:0_temp0.7_20250214111531_trial_0.json---------
# /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before bedrock/meta.llama3-1-70b-instruct-v1:0 0.7 0 bedrock 10
# Prompt text for ...  output_sample_27.txt
# Processing file: output_sample_27.txt
# Prompt text for ...  output_sample_33.txt
# Processing file: output_sample_33.txt
# Prompt text for ...  output_sample_26.txt
# Processing file: output_sample_26.txt
# Prompt text for ...  output_sample_18.txt
# Processing file: output_sample_18.txt
# Prompt text for ...  output_sample_24.txt
# Processing file: output_sample_24.txt
# Prompt text for ...  output_sample_25.txt
# Processing file: output_sample_25.txt
# Prompt text for ...  output_sample_30.txt
# Processing file: output_sample_30.txt
# Prompt text for ...  output_sample_19.txt
# Processing file: output_sample_19.txt
# Prompt text for ...  output_sample_32.txt
# Processing file: output_sample_32.txt
# Prompt text for ...  output_sample_31.txt
# Processing file: output_sample_31.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_30_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_35.txt
# Processing file: output_sample_35.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_19_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_21.txt
# Processing file: output_sample_21.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_18_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_20.txt
# Processing file: output_sample_20.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_25_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_34.txt
# Processing file: output_sample_34.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_27_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_22.txt
# Processing file: output_sample_22.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_24_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_36.txt
# Processing file: output_sample_36.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_33_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_37.txt
# Processing file: output_sample_37.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_21_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_23.txt
# Processing file: output_sample_23.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_31_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_8.txt
# Processing file: output_sample_8.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_32_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_9.txt
# Processing file: output_sample_9.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_26_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_4.txt
# Processing file: output_sample_4.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_37_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_5.txt
# Processing file: output_sample_5.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_35_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_7.txt
# Processing file: output_sample_7.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_22_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_6.txt
# Processing file: output_sample_6.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_23_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_2.txt
# Processing file: output_sample_2.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_36_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_3.txt
# Processing file: output_sample_3.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-190/exp_15_2/func_src_before/output_sample_9_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# ...
# Prompt text for ...  output_sample_44.txt
# Processing file: output_sample_44.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_21_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_50.txt
# Processing file: output_sample_50.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_34_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_51.txt
# Processing file: output_sample_51.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_36_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_45.txt
# Processing file: output_sample_45.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_20_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.jsonResponse saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_37_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
#
# Prompt text for ...  output_sample_53.txt
# Processing file: output_sample_53.txt
# Prompt text for ...  output_sample_47.txt
# Processing file: output_sample_47.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_19_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_46.txt
# Processing file: output_sample_46.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_23_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_52.txt
# Processing file: output_sample_52.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_25_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_56.txt
# Processing file: output_sample_56.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_51_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_42.txt
# Processing file: output_sample_42.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_53_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_43.txt
# Processing file: output_sample_43.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_44_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_57.txt
# Processing file: output_sample_57.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_50_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_8.txt
# Processing file: output_sample_8.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_52_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_41.txt
# Processing file: output_sample_41.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_56_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_55.txt
# Processing file: output_sample_55.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_45_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_69.txt
# Processing file: output_sample_69.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_41_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_57_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_68.txt
# Processing file: output_sample_68.txt
# Prompt text for ...  output_sample_54.txt
# Processing file: output_sample_54.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_46_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_40.txt
# Processing file: output_sample_40.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_42_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_9.txt
# Processing file: output_sample_9.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_68_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_4.txt
# Processing file: output_sample_4.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_43_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_59.txt
# Processing file: output_sample_59.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_55_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_65.txt
# Processing file: output_sample_65.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_8_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_70.txt
# Processing file: output_sample_70.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_54_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_64.txt
# Processing file: output_sample_64.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_40_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_58.txt
# Processing file: output_sample_58.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_4_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_5.txt
# Processing file: output_sample_5.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_9_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_7.txt
# Processing file: output_sample_7.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_69_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_66.txt
# Processing file: output_sample_66.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_64_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_67.txt
# Processing file: output_sample_67.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_59_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_6.txt
# Processing file: output_sample_6.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_70_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_2.txt
# Processing file: output_sample_2.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_7_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_63.txt
# Processing file: output_sample_63.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_67_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_62.txt
# Processing file: output_sample_62.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_5_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_3.txt
# Processing file: output_sample_3.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_65_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_1.txt
# Processing file: output_sample_1.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_6_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_60.txt
# Processing file: output_sample_60.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_2_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_48.txt
# Processing file: output_sample_48.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_58_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_49.txt
# Processing file: output_sample_49.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_66_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_61.txt
# Processing file: output_sample_61.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_62_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_12.txt
# Processing file: output_sample_12.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_63_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_13.txt
# Processing file: output_sample_13.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_1_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_39.txt
# Processing file: output_sample_39.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_60_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_11.txt
# Processing file: output_sample_11.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_48_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_10.txt
# Processing file: output_sample_10.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_13_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_38.txt
# Processing file: output_sample_38.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_49_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_14.txt
# Processing file: output_sample_14.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_61_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_28.txt
# Processing file: output_sample_28.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_12_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_29.txt
# Processing file: output_sample_29.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_39_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_15.txt
# Processing file: output_sample_15.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_11_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_38_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Prompt text for ...  output_sample_17.txt
# Processing file: output_sample_17.txt
# Prompt text for ...  output_sample_16.txt
# Processing file: output_sample_16.txt
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_14_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_10_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_29_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_17_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_15_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_16_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_28_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_32_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_47_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# Response saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_sample_3_response_bedrock_meta.llama3-1-70b-instruct-v1:0_trial_0.json
# ------------Responses saved to /Users/ic/Desktop/LLM-as-Static-Proxy-Test/experiments_latest/cwe-476/exp_25/func_src_after/output_responses_bedrock_meta.llama3-1-70b-instruct-v1:0_temp0.7_20250214125726_trial_0.json---------

# %%
import json
import openai
import sys
from concurrent.futures import ThreadPoolExecutor, as_completed
import os
from together import Together
import re

def query_openai(client, prompt, model, temperature, max_tokens, mode):
    """
    Queries the OpenAI API with the specified parameters and returns the response.
    """
    try:
        if mode == "o1":
            client = openai
            response = client.chat.completions.create(
                model=model,
                messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 500 tokens."},
                    {"role": "user", "content": prompt},
                ])
            return response
        elif mode == "together":
            os.environ['TOGETHER_API_KEY'] = ''
            client = Together()
            response = client.chat.completions.create(
                model="deepseek-ai/DeepSeek-R1",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant. Limit your response to 130 tokens."},
                    {"role": "user", "content": prompt},
                ],
                temperature=temperature,
                top_p=1,
                seed=42
            )
            print(response)
            return response
        else:
            response = client.chat.completions.create(
                model=model,
                messages=[
                    {"role": "system", "content": "You are a helpful assistant."},
                    {"role": "user", "content": prompt}
                ],
                temperature=temperature,
                max_tokens=max_tokens,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stream=False
            )
            return response
    except Exception as e:
        print(f"An error occurred: {e}")
        return None


def determine_vulnerability(response):
    prompt = f"Determine if the following response indicates a vulnerability was found:\n\n{response}\n\nRespond ONLY with 'vulnerable' or 'non-vulnerable'. Answer in this format: ['response': 'vulnerable'] or  ['response': 'non-vulnerable']"
    completion = query_openai(
        client=openai,
        prompt=prompt,
        model="deepseek-ai/DeepSeek-R1",
        temperature=0.6,
        max_tokens=4096,
        mode = "together"
    )
    # if completion is not None:
    #     result = completion.choices[0].message.content.strip().lower()
    #     if result not in ["vulnerable", "non-vulnerable"]:
    #         result = "inconclusive"
    #     return result
    # else:
    #     return "ERROR"  # Return ERROR if there's an issue with the API call
     # Define the regex pattern to match the desired string
    pattern = r"n<\/think>\n\n\['response': '(vulnerable|non-vulnerable)'\]"

    if completion is not None:
        # Retrieve the content, strip whitespace, and ensure it's in lowercase
        content = completion.choices[0].message.content.strip().lower()

        # Use regex to find matches
        match = re.search(pattern, content)

        # Check if the regex found a valid match
        if match:
            # Extract the matched group which will be either 'vulnerable' or 'non-vulnerable'
            result = match.group(1)
            print("!!!!!!!!!!!!!!!!!!!!!!!!!result is....", result)
        else:
            # Set result to 'inconclusive' if the pattern does not match
            result = "inconclusive"

        return result
    else:
        # Return "ERROR" if there's an issue with the API call
        return "ERROR"

def process_json(input_file, output_file, max_workers=10):
    """
    Processes a JSON file in a multithreaded manner.
    
    :param input_file: Path to input JSON file
    :param output_file: Path to save output JSON results
    :param max_workers: Number of threads for concurrent processing
    """
    with open(input_file, 'r') as f:
        data = json.load(f)

    results = {}
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_key = {executor.submit(determine_vulnerability, response): key for key, response in data.items()}

        for future in as_completed(future_to_key):
            key = future_to_key[future]
            try:
                results[key] = future.result()
            except Exception as e:
                print(f"Error processing {key}: {e}")
                results[key] = "ERROR"

    with open(output_file, 'w') as f:
        json.dump(results, f, indent=4)


if __name__ == "__main__":
    if len(sys.argv) != 3:
        print("Usage: python script.py <input_json_file> <output_json_file>")
        sys.exit(1)

    input_file = sys.argv[1]
    output_file = sys.argv[2]

    # Adjust max_workers as needed based on API limits
    process_json(input_file, output_file, max_workers=5)

# %%
# If necessary, install the openai Python library by running 
# pip install openai

from openai import OpenAI

client = OpenAI(
	base_url="https://ue4xb2y39sfo803n.us-east-1.aws.endpoints.huggingface.cloud/v1/", 
	api_key="" 
)

chat_completion = client.chat.completions.create(
	model="tgi",
	messages=[
	{
		"role": "user",
		"content": "What is deep learning?"
	}
],
	top_p=None,
	temperature=None,
	max_tokens=150,
	stream=False,
	seed=None,
	stop=None,
	frequency_penalty=None,
	presence_penalty=None
)
print(chat_completion.choices[0].message.content)
#for message in chat_completion:
#	print(message.choices[0].delta.content, end="")

# %%
message.choices[0].delta.content, end=""

# %%
def query_openai(prompt, model, temperature, mode):
    """
    Queries the OpenAI API with the specified parameters and returns the response.
    """
    try:
        client = openai

        if mode == "deepseek":
            client = OpenAI(
                base_url="https://huggingface.co/api/inference-proxy/together",
                api_key=""
            )

        response = client.chat.completions.create(
            model=model,
            messages=[
                {
                    "role": "system",
                    "content": "You are a helpful assistant. You must LIMIT YOUR RESPONSE TO 130 TOKENS.",
                },
                {"role": "user", "content": prompt},
            ],
            temperature=temperature,
            max_tokens=130,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            stream=False
        )
        return response
    except Exception as e:
        print(f"An error occurred during API query: {e}")
    return None


def extract_response_content(response):
    """
    Extracts the content from the API response for serialization.
    """
    try:
        return response.choices[0].message.content
    except (KeyError, TypeError) as e:
        print(f"Error extracting response content: {e}")
        print("Full response:", response)
    return None

# %%
model ="deepseek-ai/DeepSeek-R1"
mode = "deepseek"
temperature = 0.7
response = query_openai("What is the capital of France?", model, temperature, mode)
content = extract_response_content(response)

# %%
content

# %%
from openai import OpenAI

client = OpenAI(
	base_url="https://huggingface.co/api/inference-proxy/together",
	api_key=""
)

messages = [
	{
		"role": "user",
		"content": "What is the capital of France?"
	}
]

completion = client.chat.completions.create(
	model="deepseek-ai/DeepSeek-R1", 
	messages=messages, 
	max_tokens=500
)

print(completion.choices[0].message)

# %%
completion.choices[0].message.content
